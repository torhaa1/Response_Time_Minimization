# %% [markdown]
# ## Preprocessing of police district data - Nordland district
#
# ### Preprocessing steps for ALL police districts:
# #### 1. Process road network
# 1. Import polygons of the relevant counties/municipalities
# 2. Subtract polygons of the municipalities that are not part of the police district
# 3. Import OSMnx road network from the resulting polygon
# 4. Impute edge speeds and travel times
# 5. Compute node centrality -> save as CSV
# 6. Save road network (with edge speeds and travel times) as GraphML
#
# #### 2. Process population data
# 1. Subtract polygons of the municipalities that are not part of the police district
# 2. Import and clip population data to the resulting polygon
# 3. Save population data as GeoJSON
#
# #### General notes:
# - Save and Load all data in the default CRS: WGS84 (EPSG:4326)
# - Transform data to correct UTM zone when needed for analysis. UTM zone 33N (EPSG:32633)

# %%
# import watermark
# %reload_ext watermark
# %watermark
# Out:
# Last updated: 2024-04-13T11:14:19.738112+02:00
#
# Python implementation: CPython
# Python version       : 3.11.6
# IPython version      : 8.22.2
#
# Compiler    : MSC v.1935 64 bit (AMD64)
# OS          : Windows
# Release     : 10
# Machine     : AMD64
# Processor   : Intel64 Family 6 Model 158 Stepping 10, GenuineIntel
# CPU cores   : 12
# Architecture: 64bit

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import shapely
from shapely.geometry import Point, LineString, Polygon, MultiPolygon, mapping
from shapely.ops import nearest_points, unary_union
import pyproj
import geopandas as gpd
import osmnx as ox
import networkx as nx
import pandana as pdna
import igraph as ig
import pulp

pd.set_option('display.float_format', lambda x: '%.3f' % x)
ox.settings.log_console=True
ox.settings.use_cache=True
# %watermark -w
# %watermark -iv
# Out:
# Watermark: 2.4.3
#
# networkx  : 3.2.1
# pulp      : 2.8.0
# pyproj    : 3.6.1
# osmnx     : 1.9.1
# geopandas : 0.14.3
# matplotlib: 3.8.3
# pandana   : 0.7
# igraph    : 0.11.4
# shapely   : 2.0.3
# pandas    : 2.2.1
# numpy     : 1.26.4

# %% [markdown]
# ### 1. Process road network
#
# Preprocessing steps for Øst police district as an example:
# 1. Import polygons of Akershus and Østfold counties
# 2. Subtract polygons of Asker, Bærum, Jevnaker and Lunner
# 3. Import OSMnx road network from the resulting polygon
# 4. Impute edge speeds and travel times
# 5. Compute node centrality -> save as CSV
# 6. Change graph CRS from WGS84 to UTM33N
# 7. Save the network to a file -> save as GraphML

# %%
# import all police districts from file - geojson did not work for some reason
# police_districts_gdf = gpd.read_file("../data/police_districts/Basisdata_0000_Norge_25833_PolitiSonerDistrikter_GeoJSON/Basisdata_0000_Norge_25833_PolitiSonerDistrikter_GeoJSON.geojson")
# police_districts_gdf = gpd.read_file("../data/police_districts/Basisdata_0000_Norge_25833_PolitiSonerDistrikter_GML/Basisdata_0000_Norge_25833_PolitiSonerDistrikter_GML.gml", driver='GML')
districts_gdf = gpd.read_file("../data/police_districts/Basisdata_0000_Norge_25833_PolitiSonerDistrikter_FGDB/Basisdata_0000_Norge_25833_PolitiSonerDistrikter_FGDB.gdb", driver='FileGDB', layer='PolitiDistrikt')
districts_gdf.head(2)
# Out:
#           objtype                               lokalid  \
# 0  Politidistrikt  87fae7b1-8dd5-4421-8aa7-a1fb0444a6d5
# 1  Politidistrikt  a7e37bed-72ec-4751-8d5c-116f3cc29bcb
#
#                                             navnerom versjonid  \
# 0  https://data.geonorge.no/sosi/administrativeen...  20221010
# 1  https://data.geonorge.no/sosi/administrativeen...  20221010
#
#            oppdateringsdato            datauttaksdato  \
# 0 2022-09-07 00:00:00+00:00 2022-09-23 10:12:13+00:00
# 1 2022-09-07 00:00:00+00:00 2022-09-23 10:12:13+00:00
#
#                   geodataeier geodataprodusent          politidistriktnavn  \
# 0  Politi- og lensmannsetaten       Kartverket  Sysselmesteren på Svalbard
# 1  Politi- og lensmannsetaten       Kartverket  Sysselmesteren på Svalbard
#
#    politidistriktnummer  SHAPE_Length       SHAPE_Area  \
# 0                    62    194823.787   2982857059.273
# 1                    62   1765995.016 132623763796.629
#
#                                             geometry
# 0  MULTIPOLYGON (((622945.587 8231320.844, 621945...
# 1  MULTIPOLYGON (((642503.317 8974589.147, 643343...

# %%
# Change CRS from UTM33N to WGS84
print("CRS of the districts_gdf:", districts_gdf.crs)
districts_gdf = districts_gdf.to_crs(epsg=4326)
print("CRS of the districts_gdf:", districts_gdf.crs)
# Out:
# CRS of the districts_gdf: EPSG:25833
# CRS of the districts_gdf: EPSG:4326

# %%
def clean_data(police_districts_gdf):
    # Drop column: 'objtype'
    police_districts_gdf = police_districts_gdf.drop(columns=['objtype', 'navnerom', 'versjonid', 'oppdateringsdato', 'datauttaksdato', 'geodataeier', 'geodataprodusent'])
    police_districts_gdf = police_districts_gdf.rename(columns={'lokalid': 'lokalID', 'politidistriktnavn': 'districtName', 'politidistriktnummer': 'districtID'})
    
    # If districtName contains substring Svalbard in any upper/lower case combination, then delete row
    police_districts_gdf = police_districts_gdf[~police_districts_gdf['districtName'].str.contains('svalbard', case=False)]
    return police_districts_gdf

districts_clean = clean_data(districts_gdf.copy())
print("Shape of the cleaned dataset:", districts_clean.shape)
districts_clean.head(4)
# Out:
# Shape of the cleaned dataset: (12, 6)
#                                 lokalID              districtName  districtID  \
# 5  e1762655-ad1e-4eaa-aa25-e7713bffea52       Oslo politidistrikt         201
# 6  0864cb4d-a697-46ab-9a1f-ac4f802ae57f        Øst politidistrikt         202
# 7  f6acc5e9-84a1-4c8f-8eb1-69d6da1ef1e8  Innlandet politidistrikt         203
# 8  d6c66ee5-09f7-46b8-a5c2-1a667c76820d    Sør-Øst politidistrikt         204
#
#    SHAPE_Length      SHAPE_Area  \
# 5    240454.396  1233150525.719
# 6    675838.072  9817130626.535
# 7   1413687.019 52403856403.783
# 8   1028797.167 35223823522.815
#
#                                             geometry
# 5  MULTIPOLYGON (((10.73101 59.87718, 10.71810 59...
# 6  MULTIPOLYGON (((11.15351 59.07926, 11.12656 59...
# 7  MULTIPOLYGON (((10.77218 60.21377, 10.77231 60...
# 8  MULTIPOLYGON (((9.96977 58.72045, 9.78836 58.6...

# %%
# plot the different districtNames
fig, ax = plt.subplots(figsize=(5, 5))
districts_clean.plot(ax=ax, column='districtName', legend=True, legend_kwds={'bbox_to_anchor': (1, 1), 'loc': 'upper left', 'prop': {'size': 10}})
ax.get_xaxis().set_visible(False); ax.get_yaxis().set_visible(False)
plt.title('Police districts in Norway')
plt.tight_layout(); plt.show()

# %% [markdown]
# Now we have the polygon for the Øst police district. Note that this polygon does not have any coordinate system (CRS) info, we have to add this.
# For GeoDataFrames, we simply use the `to_crs` method, while for shapely polygons we use the `pyproj` library.

# %%
Nordland_gdf = districts_clean[districts_clean['districtName'] == 'Nordland politidistrikt']
Nordland_poly = Nordland_gdf.iloc[0].geometry
Nordland_poly
# Out:
# <MULTIPOLYGON (((11.298 66.404, 11.522 66.625, 11.566 66.668, 11.567 66.669,...>

# %% [markdown]
# #### Step 2.5 - (OPTIONAL) Only add a subset of neighbouring district to original district
#
# 1) Create main graph (road network) of Original police district + relevant parts of neighbouring police districts.
# 2) Create subgraph of only Original police district. This will be used to only simulate Car and Event points in the Original police district.

# %%
# Manually define polygon points for the relevant parts from the neighbouring district of interest 
# Fetched from OpenStreetMap in WGS84 (EPSG:4326) format
# OBS: Shapely construct polygons in counter-clockwise order, so the points should be defined in a sequential order
coords = [
    (15.4, 69.885),  # longitude and latitude of point 1
    (12.061, 67.722),  # long/lat of point 2
    (16.1, 68.29),
    (16.95, 67.834),
    (18.573, 68.899),
    (16.3829, 68.7594),
    (16.74, 69.233),
]
neighbouring_district_polygon = Polygon(coords) # Create Shapely polygon from point coordinates


# optional preliminary steps to ensure a valid polygon
neighbouring_district_polygon = neighbouring_district_polygon.buffer(0) # buffer by 0 to ensure valid polygon
# neighbouring_district_polygon = neighbouring_district_polygon.simplify(0.0001, preserve_topology=False) # simplify polygon

NordlandExt_gdf = gpd.GeoDataFrame(index=[0], crs='EPSG:4326', geometry=[neighbouring_district_polygon])

# plot the resulting polygon, the intersection and the boundary points
fig, ax = plt.subplots(figsize=(4,3))  # Adjust the size values as needed
NordlandExt_gdf.plot(ax=ax, color='lightgreen', alpha=0.7)
Nordland_gdf.plot(ax=ax, color='lightblue', alpha=0.7)
x, y = zip(*coords)
ax.scatter(x, y, color='red', s=10)
x, y = neighbouring_district_polygon.exterior.xy
ax.plot(x, y, color='blue', linewidth=1)
for i, coord in enumerate(coords):
    ax.text(coord[0], coord[1], f'{i+1}', fontsize=10, color='black')
ax.get_xaxis().set_visible(False); ax.get_yaxis().set_visible(False)
plt.title('Nordland subset area')
plt.tight_layout(); plt.show()

NordlandExt_poly = NordlandExt_gdf.iloc[0].geometry
# NordlandExt_poly

# %%
# %%time
# Step 3. Import OSMnx road network from the resulting polygon
# Nordland_graph_edges = ox.graph_to_gdfs(Nordland_graph, nodes=False, edges=True)
Nordland_graph = ox.graph_from_polygon(Nordland_poly, network_type="drive", simplify=True, retain_all=False, truncate_by_edge=False, custom_filter=None)
# NordlandExt_graph = ox.graph_from_polygon(NordlandExt_poly, network_type="drive", simplify=True, retain_all=False, truncate_by_edge=False, custom_filter=None)

# Backup - fetch from OSM boundaries of Rogaland (approximation of police district)
# Vestland_graph = ox.graph_from_place('Vestland, Norway', network_type="drive_service") # originally in WGS84 (EPSG:4326)
# Out:
# c:\ProgramData\miniconda3\envs\MCLP_env\Lib\site-packages\osmnx\_overpass.py:211: UserWarning: This area is 38 times your configured Overpass max query area size. It will automatically be divided up into multiple sub-queries accordingly. This may take a long time.
#   multi_poly_proj = utils_geo._consolidate_subdivide_geometry(poly_proj)
# CPU times: total: 1min 1s
# Wall time: 1min 13s

# %%
# extended area
NordlandExt_graph = ox.graph_from_polygon(NordlandExt_poly, network_type="drive", simplify=True, retain_all=False, truncate_by_edge=False, custom_filter=None)
# Out:
# c:\ProgramData\miniconda3\envs\MCLP_env\Lib\site-packages\osmnx\_overpass.py:211: UserWarning: This area is 14 times your configured Overpass max query area size. It will automatically be divided up into multiple sub-queries accordingly. This may take a long time.
#   multi_poly_proj = utils_geo._consolidate_subdivide_geometry(poly_proj)

# %%
# plot boundary and road network
Nordland_graph_edges = ox.graph_to_gdfs(Nordland_graph, nodes=False, edges=True)
NordlandExt_graph_edges = ox.graph_to_gdfs(NordlandExt_graph, nodes=False, edges=True)
# NordlandExt_graph_edges2 = ox.graph_to_gdfs(NordlandExt_graph2, nodes=False, edges=True)

# Plot the road networks with the police district as background
fig, ax = plt.subplots(figsize=(7, 7))
Nordland_graph_edges.plot(ax=ax, color='gray', linewidth=0.5)
NordlandExt_graph_edges.plot(ax=ax, color='red', linewidth=0.5)
# NordlandExt_graph_edges2.plot(ax=ax, color='blue', linewidth=0.5)
Nordland_gdf.boundary.plot(ax=ax, color='green', linewidth=2)
plt.tight_layout(); plt.show()

# %% [markdown]
# Note that the north and south parts of the road network is not connected because one have to take a ferry between the two parts.

# %%
# combine the two graphs
combined_graph = nx.compose(Nordland_graph, NordlandExt_graph)

# %%
# impute speed on all edges missing data
combined_graph = ox.speed.add_edge_speeds(combined_graph)

# calculate travel time (seconds) for all edges
combined_graph = ox.speed.add_edge_travel_times(combined_graph)
Nordland_graph = combined_graph

# # converting graph to node and edge GeoPandas GeoDataFrames
Nordland_gdf_nodes, Nordland_gdf_edges = ox.graph_to_gdfs(Nordland_graph)
print(f"type of Nordland_gdf_nodes:{type(Nordland_gdf_nodes)}")
Nordland_gdf_edges.keys()
# Out:
# type of Nordland_gdf_nodes:<class 'geopandas.geodataframe.GeoDataFrame'>
# Index(['osmid', 'lanes', 'name', 'highway', 'maxspeed', 'width', 'oneway',
#        'reversed', 'length', 'geometry', 'speed_kph', 'travel_time', 'bridge',
#        'ref', 'tunnel', 'junction', 'access', 'service'],
#       dtype='object')

# %%
Nordland_gdf_edges.head(2)
# Out:
#                                           osmid lanes               name  \
# u         v          key
# 201344755 8977449204 0    [59426322, 167195250]     2  Svenningdalsvegen
#           5752176302 0     [59426322, 59426323]     2  Svenningdalsvegen
#
#                                highway  maxspeed width  oneway       reversed  \
# u         v          key
# 201344755 8977449204 0    unclassified        70     7   False  [False, True]
#           5752176302 0    unclassified  [70, 60]     7   False           True
#
#                            length  \
# u         v          key
# 201344755 8977449204 0   3128.367
#           5752176302 0    241.094
#
#                                                                    geometry  \
# u         v          key
# 201344755 8977449204 0    LINESTRING (13.40678 65.44126, 13.40677 65.441...
#           5752176302 0    LINESTRING (13.40678 65.44126, 13.40678 65.441...
#
#                           speed_kph  travel_time bridge  ref tunnel junction  \
# u         v          key
# 201344755 8977449204 0       70.000      160.900    NaN  NaN    NaN      NaN
#           5752176302 0       65.000       13.400    NaN  NaN    NaN      NaN
#
#                          access service
# u         v          key
# 201344755 8977449204 0      NaN     NaN
#           5752176302 0      NaN     NaN

# %% [markdown]
# Here we verify the edges has new attributes: `speed_kph` and `travel_time`.

# %%
# # Export the graph to a file in GraphML format
ox.save_graphml(Nordland_graph, "../data/Nordland/NordlandDriveImputed.graphml")

# %% [markdown]
# Next is computing the closeness centrality for each node in the network. This is a measure of how central a node is in the network. It is calculated as the reciprocal of the sum of the shortest path distances from the node to all other nodes in the network. The higher the value, the more central the node is.
# Current implementation uses the `networkx` library, which is quite slow and memory intensive for this operation. At least it is only computed once and saved to a CSV file.
# TODO: Implement a faster method for computing centrality.

# %%
# %%time
# 5. Compute node centrality - using NetworkX (suitable for small graphs)
# Calculate closeness centrality
# Nordland_centrality = nx.closeness_centrality(Nordland_graph, distance='travel_time')
# Nordland_gdf_nodes['closeness_centrality'] = Nordland_gdf_nodes.index.map(Nordland_centrality)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
# 5. Compute node centrality - using igraph (suitable for large graphs)

# converting the networkx graph to an igraph graph
osmids = list(Nordland_graph.nodes)
Nordland_graph = nx.relabel.convert_node_labels_to_integers(Nordland_graph)

# give each node its original osmid as attribute since we relabeled them
osmid_values = {k: v for k, v in zip(Nordland_graph.nodes, osmids)}
nx.set_node_attributes(Nordland_graph, osmid_values, "osmid")

# %%
# %%time
# convert networkx graph to igraph
Nordland_igraph= ig.Graph(directed=True)
Nordland_igraph.add_vertices(Nordland_graph.nodes)
Nordland_igraph.add_edges(Nordland_graph.edges())
Nordland_igraph.vs["osmid"] = osmids
Nordland_igraph.es["travel_time"] = list(nx.get_edge_attributes(Nordland_graph, "travel_time").values())
# Out:
# CPU times: total: 31.2 ms
# Wall time: 80.4 ms

# %%
assert len(Nordland_graph.nodes()) == Nordland_igraph.vcount()
assert len(Nordland_graph.edges()) == Nordland_igraph.ecount()

# %%
# check for any non-positive travel time values
non_positive_edges = [e for e in Nordland_igraph.es if e["travel_time"] <= 0]
print(f"Number of non-positive travel time edges: {len(non_positive_edges)}")

# show the non-positive travel time edges
non_positive_edges[:]

# inspect the non-positive travel time edges, if small we can set them to a small positive value
for e in non_positive_edges:
    print(e.tuple, e["travel_time"])

# Set the non-positive travel time edges to a small positive value
for e in non_positive_edges:
    e["travel_time"] = 1

# Re-check for any non-positive travel time values
non_positive_edges = [e for e in Nordland_igraph.es if e["travel_time"] <= 0]
print(f"Number of non-positive travel time edges (2nd time): {len(non_positive_edges)}")

# this returned 6 non-positive travel time edges. This can happen when the travel time is not imputed for some edges.
# We can either remove these edges or impute the travel time for them. Here we added a small positive value to the travel time.
# Out:
# Number of non-positive travel time edges: 0
# Number of non-positive travel time edges (2nd time): 0

# %%
# %%time
# closeness centrality with igraph - incoming and outgoing paths
closeness1 = Nordland_igraph.closeness(vertices=None, mode="all", cutoff=None, weights="travel_time", normalized=True)
max_closeness1 = np.argmax(closeness1)
# Out:
# CPU times: total: 11.9 s
# Wall time: 15 s

# %%
# %%time
# betweenness centrality with igraph
betweenness1 = Nordland_igraph.betweenness(vertices=None, directed=True, cutoff=None, weights="travel_time")
max_betweenness1 = np.argmax(betweenness1)
# Out:
# CPU times: total: 15.9 s
# Wall time: 18.5 s

# %%
# inspect the maximum centrality values
print(f"Max closeness centrality (1st method): {max_closeness1}, {closeness1[max_closeness1]}")
print(f"Max betweenness centrality (1st method): {max_betweenness1}, {betweenness1[max_betweenness1]}")
# Out:
# Max closeness centrality (1st method): 15193, 0.000181922688437865
# Max betweenness centrality (1st method): 6589, 69299803.0

# %%
# adding the centrality values to the node GeoDataFrame
Nordland_gdf_nodes["closeness_centrality"] = closeness1 # all nodes
Nordland_gdf_nodes["betweenness_centrality"] = betweenness1 # all nodes

# %%
Nordland_gdf_nodes.head(2)
# Out:
#                y      x  street_count highway                   geometry  \
# osmid
# 201344755 65.441 13.407             3     NaN  POINT (13.40678 65.44126)
# 287117982 65.299 12.650             3     NaN  POINT (12.64972 65.29911)
#
#            closeness_centrality  betweenness_centrality
# osmid
# 201344755                 0.000               23593.000
# 287117982                 0.000            42594727.000

# %%
# Plot the road network with the closeness centrality values as node colors - using OSMnx
# node_color
nc = Nordland_gdf_nodes["closeness_centrality"]
nc = nc / nc.max()
nc = plt.cm.plasma(nc)

# plot the road network with the closeness centrality values as node colors
fig, ax = ox.plot_graph(Nordland_graph, node_size=5, node_color=nc, edge_color="w", edge_linewidth=0.2, bgcolor="k", show=False, close=False)
plt.show()

# # Plot the road network with the police district as background
# fig, ax = ox.plot_graph(Nordland_graph, node_size=0, edge_linewidth=0.5, bgcolor='black', show=False, close=False)
# Nordland_graph.boundary.plot(ax=ax, color='green', linewidth=2)
# plt.title('Innlandet police district with road network')
# plt.tight_layout(); plt.show()

# %%
# Plot the road network with the betweenness centrality values as node colors - using OSMnx
# node_color
scale_factor = 10
nc = Nordland_gdf_nodes["betweenness_centrality"]
nc = scale_factor * nc / nc.max()
nc = plt.cm.plasma(nc)

# plot the road network with the betweenness centrality values as node colors
fig, ax = ox.plot_graph(Nordland_graph, node_size=5, node_color=nc, edge_color="w", edge_linewidth=0.2, bgcolor="k", show=False, close=False)
plt.show()

# %%
# Save centrality to CSV file with 'closeness_centrality' and 'betweenness' columns and 'osmid' as index

# Prepare the node GeoDataFrame for saving to CSV file with 'closeness_centrality' columns and 'osmid' as index
Nordland_gdf_nodes_centrality = Nordland_gdf_nodes[["closeness_centrality", "betweenness_centrality"]]
Nordland_gdf_nodes_centrality.to_csv("../data/Nordland/NordlandNodeCentrality.csv", index=True) # recently changed this to True

# Load centrality from CSV file
Nordland_gdf_nodes_imported = pd.read_csv("../data/Nordland/NordlandNodeCentrality.csv", index_col=0)
Nordland_gdf_nodes_imported.head(2)

# print the single highest closeness centrality value
max_closeness = Nordland_gdf_nodes_imported["closeness_centrality"].max()
print(f"Max closeness centrality: {max_closeness}")
# Out:
# Max closeness centrality: 0.0001819226884378

# %%
Nordland_gdf_nodes_imported.head(2)
# Out:
#            closeness_centrality  betweenness_centrality
# osmid
# 201344755                 0.000               23593.000
# 287117982                 0.000            42594727.000

# %% [markdown]
# The CRS of the road network have remained unchanged as WGS4 (EPSG:4326).
# Conversion to UTM33N (EPSG:32633) is done after importing the network and before any analysis.

# %% [markdown]
# ### 2. Process population data
# 1. Import counties/municipalitiy population data for the police district.
# 2. Import and clip population data to the resulting polygon.
# 3. Save population data as GeoJSON.
#
# Inland police district consists of the counties Hedmark and Oppland.

# %%
# Step 1. Import counties/municipalitiy population data for the police district
# Load Nordland population data
# Nordland_population_path = "../data/Nordland/ssb_data/v_ru250m_2023_rutenett.geojson"
Nordland_population_path = "../data/Nordland/ssb_data/v_ru250m_2023_rutenett.geojson"
# Nordland_population_path = "../data/Nordland/ssb_data/Nordland/v_ru250m_2023_rutenett.geojson"
# rogaland_population_path = "../data/Nordland/ssb_data/rogaland/v_ru250m_2023_rutenett.geojson"
# jevnaker_population_path = "../data/Nordland/ssb_data/jevnaker/v_ru250m_2023_rutenett.geojson"

# Nordland_population = gpd.read_file(Nordland_population_path)
# agder_population = gpd.read_file(agder_population_path)
Nordland_population = gpd.read_file(Nordland_population_path)
# rogaland_population = gpd.read_file(rogaland_population_path)
# jevnaker_population = gpd.read_file(jevnaker_population_path)

# rename columns
# for gdf in [agder_population, Nordland_population, rogaland_population]:
#     gdf.columns = ['id', 'population', 'geometry']
Nordland_population.columns = ['id', 'population', 'geometry'] # rename column names

# %%
# %%time
# Step 2. Import and clip population data to the resulting polygon.
# Already have 'Nordland_poly' from previous steps to clip the population data

# combine the population data
# population_gdf = pd.concat([agder_population, vestland_population, rogaland_population], axis=0)
population_gdf = Nordland_population

# clip the population data to the resulting polygon
clipped_population = gpd.clip(population_gdf, Nordland_poly)
# clipped_population = Nordland_population
# Out:
# CPU times: total: 8.75 s
# Wall time: 9.75 s

# %%
# plot the clipped population data, with the combined polygon as outline and the population colored by population size
fig, ax = plt.subplots(figsize=(6,6))  # Adjust the size values as needed
Nordland_gdf.boundary.plot(ax=ax, color='green', linewidth=1, alpha=0.3, zorder=-1)

# set custom range for the color map
vmin, vmax = 0, 50
clipped_population.plot(ax=ax, column='population', cmap='Reds', legend=True, alpha=0.7, vmin=vmin, vmax=vmax)
# Nordland_population.plot(ax=ax, column='population', cmap='jet', legend=True, alpha=0.7)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title('Nordland police district: Population data')
plt.tight_layout(); plt.show()

# %%
# Step 3. Save population data as GeoJSON.

# Save the clipped population data to a file
clipped_population.to_file("../data/Nordland/NordlandPopulation.geojson", driver="GeoJSON")

# load the population data from the file
Nordland_population_imported = gpd.read_file("../data/Nordland/NordlandPopulation.geojson")
Nordland_population_imported.head(2)
# Out:
#                id  population  \
# 0  23615007235500           3
# 1  23672507237500           1
#
#                                             geometry
# 0  POLYGON ((12.03847 65.21350, 12.03822 65.21574...
# 1  POLYGON ((12.15931 65.23380, 12.15907 65.23604...

# %%
# plot the imported population data for verification
fig, ax = plt.subplots(figsize=(4,4))  # Adjust the size values as needed
Nordland_gdf.boundary.plot(ax=ax, color='green', linewidth=1, alpha=0.3, zorder=-1)
Nordland_population_imported.plot(ax=ax, column='population', cmap='Reds', legend=True, alpha=0.7, vmin=vmin, vmax=vmax)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title('Nordland police district: Imported population data')
plt.tight_layout(); plt.show()

# %%
# Also save the combined polygon to a file, but cannot save polygon directly
# Convert the polygon to a GeoDataFrame with a single row
Nordland_poly_gdf = gpd.GeoDataFrame(geometry=[Nordland_poly])
Nordland_poly_gdf.to_file("../data/Nordland/NordlandCombinedPolygon.geojson", driver="GeoJSON")

# Load the combined polygon from the file
Nordland_poly_imported = gpd.read_file("../data/Nordland/NordlandCombinedPolygon.geojson")
Nordland_poly_imported.head(2)
# Out:
#                                             geometry
# 0  MULTIPOLYGON (((11.29777 66.40449, 11.52222 66...

# %%
# plot the imported combined polygon for verification
fig, ax = plt.subplots(figsize=(4,4))  # Adjust the size values as needed
Nordland_gdf.boundary.plot(ax=ax, color='green', linewidth=1, alpha=0.3, zorder=-1)
Nordland_poly_imported.boundary.plot(ax=ax, color='blue', linewidth=2)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title('Nordland police district: Imported combined polygon')
plt.tight_layout(); plt.show()
